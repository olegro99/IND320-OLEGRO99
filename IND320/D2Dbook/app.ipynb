# %% [markdown]
# # IND320 project, task 1

# %% [markdown]
# By: Ole Andreas Grøtting\
# GitHub: (https://github.com/olegro99/IND320-OLEGRO99)\
# Streamlit: [\[ind320-olegro99-grxpvhtmnnumfeeuqe8u7q.streamlit.app\]](https://ind320-olegro99-grxpvhtmnnumfeeuqe8u7q.streamlit.app/)
