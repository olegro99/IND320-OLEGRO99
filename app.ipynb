# %% [markdown]
# # IND320 Project, Task 1

# %% [markdown]
# By: Ole Andreas Grøtting\
# GitHub: https://github.com/olegro99/IND320-OLEGRO99.git \
# Streamlit: https://ind320-olegro99-grxpvhtmnnumfeeuqe8u7q.streamlit.app/
